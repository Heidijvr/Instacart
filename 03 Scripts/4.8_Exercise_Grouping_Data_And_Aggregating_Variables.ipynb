# %% [markdown]
# ## CONTENT LIST
#
# 1. Importing Libraries
# 2. Importing Data
# 3. Grouping Data
# 4. Grouping Data with agg()
# 5. Multiple Aggregations
# 6. Aggregating Data with Transform()
# 7. Deriving Columns with loc()
# 8. Exporting Data

# %% [markdown]
# ## 1. Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Importing Data

# %%
# Import 'df_ords_prods_merge' from 4.7
ords_prods_merge = pd.read_pickle(r'C:\Users\heidi\OneDrive\CareerFoundry\Achievement4 Python Fundamentals for Data Analysts\4.2.Jupyter_Fundamentals_and_Python_Data_Types\Instacart Basket Analysis 16-03-2021\02 Data\Prepared Data\ords_prods_merged.pkl')

# %%
# Create path
path = r'C:\Users\heidi\OneDrive\CareerFoundry\Achievement4 Python Fundamentals for Data Analysts\4.2.Jupyter_Fundamentals_and_Python_Data_Types\Instacart Basket Analysis 16-03-2021'

# %%
# Create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                   11.11         196                  1          0   both
# 1                   15.00         196                  1          1   both
# 2                   21.00         196                  1          1   both
# 3                   29.00         196                  1          1   both
# 4                   28.00         196                  1          1   both
#
# ...

# %% [markdown]
# ## 3. Grouping Data

# %%
# Grouping with Pandas
df.groupby('product_name')

# %% [markdown]
# ## 4. Grouping Data with agg()

# %%
# Using the agg() function to obtain mean
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Calculating mean without agg()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# ## 5. Multiple Aggregations

# %%
# Produce multiple statistics at the same time; mean, min and max.
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## 6. Aggregating Data with transform()

# %%
# Aggregating data with Transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
# 5   3367565        1             6                       2                  7
# 6    550135        1             7                       1                  9
# 7   3108588        1             8                       1                 14
# 8   2295261        1             9                       1                 16
# 9   2550362        1            10                       4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# ...

# %%
# Inform Pandas not to assign options re max number of rows to display
pd.options.display.max_rows = None

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                   11.11         196                  1          0   both
# 1                   15.00         196                  1          1   both
# 2                   21.00         196                  1          1   both
# 3                   29.00         196                  1          1   both
# 4                   28.00         196                  1          1   both
#
# ...

# %% [markdown]
# ## 7. Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15874128
# Loyal customer      10282763
# New customer         6242841
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_the_week  \
# 0    2539329        1             1                       2
# 1    2398795        1             2                       3
# 2     473747        1             3                       3
# 3    2254736        1             4                       4
# 4     431534        1             5                       4
# 5    3367565        1             6                       2
# 6     550135        1             7                       1
# 7    3108588        1             8                       1
# 8    2295261        1             9                       1
# 9    2550362        1            10                       4
# 10   2968173       15            15                       1
# 11   1870022       15            17                       2
# 12   1911383       15            18                       2
# 13   2715276       15            21                       1
# 14    487368       15            22                       1
# ...

# %% [markdown]
# ## 8. Exporting Data

# %%
# Export as pkl file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_grouping_data_1.pkl'))
